# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({"key1" : ["a", "a", None, "b", "b", "a", None],
   ....:                    "key2" : pd.Series([1, 2, 1, 2, 1, None, 1],
   ....:                                       dtype="Int64"),
   ....:                    "data1" : np.random.standard_normal(7),
   ....:                    "data2" : np.random.standard_normal(7)})
df
# Out:
#    key1  key2     data1     data2
# 0     a     1 -1.615107 -0.941220
# 1     a     2 -0.061920  1.095703
# 2  None     1 -0.393483 -0.135796
# 3     b     2 -0.677330 -1.014566
# 4     b     1 -0.418941  0.366511
# 5     a  <NA>  0.092732  0.788882
# 6  None     1 -0.369214  0.040118

# %%
grouped = df["data1"].groupby(df["key1"])

# %%
grouped.mean()
# Out:
# key1
# a   -0.528098
# b   -0.548136
# Name: data1, dtype: float64

# %%
means = df["data1"].groupby([df["key1"], df["key2"]]).mean()
means
# Out:
# key1  key2
# a     1      -1.615107
#       2      -0.061920
# b     1      -0.418941
#       2      -0.677330
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2         1        2
# key1
# a    -1.615107 -0.06192
# b    -0.418941 -0.67733

# %%
df.groupby("key1").mean()
# Out:
#       key2     data1     data2
# key1
# a      1.5 -0.528098  0.314455
# b      1.5 -0.548136 -0.324027

# %%
df.groupby("key2").mean(numeric_only=True)
# Out:
#          data1     data2
# key2
# 1    -0.699186 -0.167597
# 2    -0.369625  0.040569

# %%
df.groupby(["key1", "key2"]).mean()
# Out:
#               data1     data2
# key1 key2
# a    1    -1.615107 -0.941220
#      2    -0.061920  1.095703
# b    1    -0.418941  0.366511
#      2    -0.677330 -1.014566

# %%
df.groupby("key1", dropna=False).size()
# Out:
# key1
# a      3
# b      2
# NaN    2
# dtype: int64

# %%
df.groupby("key1").count()
# Out:
#       key2  data1  data2
# key1
# a        2      3      3
# b        2      2      2

# %%
for name, group in df.groupby("key1"):
   ....:     print(name)
   ....:     print(group)
# Out:
# a
#   key1  key2     data1     data2
# 0    a     1 -1.615107 -0.941220
# 1    a     2 -0.061920  1.095703
# 5    a  <NA>  0.092732  0.788882
# b
#   key1  key2     data1     data2
# 3    b     2 -0.677330 -1.014566
# 4    b     1 -0.418941  0.366511

# %%
for (k1, k2), group in df.groupby(["key1", "key2"]):
   ....:     print((k1, k2))
   ....:     print(group)
# Out:
# ('a', 1)
#   key1  key2     data1    data2
# 0    a     1 -1.615107 -0.94122
# ('a', 2)
#   key1  key2    data1     data2
# 1    a     2 -0.06192  1.095703
# ('b', 1)
#   key1  key2     data1     data2
# 4    b     1 -0.418941  0.366511
# ('b', 2)
#   key1  key2    data1     data2
# 3    b     2 -0.67733 -1.014566

# %%
df.groupby(["key1", "key2"])[["data2"]].mean()
# Out:
#               data2
# key1 key2
# a    1    -0.941220
#      2     1.095703
# b    1     0.366511
#      2    -1.014566

# %%
people = pd.DataFrame(np.random.standard_normal((5, 5)),
   ....:                       columns=["a", "b", "c", "d", "e"],
   ....:                       index=["Joe", "Steve", "Wanda", "Jill", "Trey"])

# %%
 people.iloc[2:3, [1, 2]] = np.nan

# %%
mapping = {"a": "red", "b": "red", "c": "blue",
   ....:            "d": "blue", "e": "red", "f" : "orange"}

# %%
by_column = people.groupby(mapping, axis="columns")

# %%
by_column.sum()
# Out:
#            blue       red
# Joe   -2.613782  0.510425
# Steve -2.599694 -0.791544
# Wanda -1.689815  1.619041
# Jill   2.037407 -0.979743
# Trey  -1.250505 -0.752676

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3  0.255672 -0.525685 -1.275269 -1.338513  0.780437
# 4 -0.707318  0.348778  0.070623  0.716280 -1.373879
# 5 -0.219672  0.037424 -0.337596 -3.951914  1.009746

# %%
columns = pd.MultiIndex.from_arrays([["US", "US", "US", "JP", "JP"],
   ....:                                     [1, 3, 5, 1, 3]],
   ....:                                     names=["cty", "tenor"])

# %%
hier_df = pd.DataFrame(np.random.standard_normal((4, 5)), columns=columns)

# %%
hier_df
# Out:
# cty          US                            JP
# tenor         1         3         5         1         3
# 0     -1.908642 -0.645856  1.738877  1.347457  1.527659
# 1      1.647574  0.560613  0.815356  0.741006 -0.230062
# 2     -0.116764  1.124767 -0.293836  1.243092  0.812316
# 3     -1.495990 -0.137272 -1.211514  0.418346  0.798146

# %%
hier_df.groupby(level="cty", axis="columns").count()
# Out:
# cty  JP  US
# 0     2   3
# 1     2   3
# 2     2   3
# 3     2   3

# %%
grouped = df.groupby("key1")
grouped["data1"].nsmallest(2)
# Out:
# key1
# a     0   -1.615107
#       1   -0.061920
# b     3   -0.677330
#       4   -0.418941
# Name: data1, dtype: float64

# %%
def peak_to_peak(arr):
   ....:     return arr.max() - arr.min()

# %%
grouped.agg(peak_to_peak)
# Out:
#       key2     data1     data2
# key1
# a        1  1.707839  2.036923
# b        1  0.258390  1.381077

# %%
tips = pd.read_csv("examples/tips.csv")

# %%
 tips["tip_pct"] = tips["tip"] / tips["total_bill"]

# %%
tips
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 0         16.99  1.01     No   Sun  Dinner     2  0.059447
# 1         10.34  1.66     No   Sun  Dinner     3  0.160542
# 2         21.01  3.50     No   Sun  Dinner     3  0.166587
# 3         23.68  3.31     No   Sun  Dinner     2  0.139780
# 4         24.59  3.61     No   Sun  Dinner     4  0.146808
# ..          ...   ...    ...   ...     ...   ...       ...
# 239       29.03  5.92     No   Sat  Dinner     3  0.203927
# 240       27.18  2.00    Yes   Sat  Dinner     2  0.073584
# 241       22.67  2.00    Yes   Sat  Dinner     2  0.088222
# 242       17.82  1.75     No   Sat  Dinner     2  0.098204
# 243       18.78  3.00     No  Thur  Dinner     2  0.159744
#
# [244 rows x 7 columns]

# %%
grouped = tips.groupby(["day", "smoker"])
grouped_pct = grouped["tip_pct"]
grouped_pct.agg("mean")
# Out:
# day   smoker
# Fri   No        0.151650
#       Yes       0.174783
# Sat   No        0.158048
#       Yes       0.147906
# Sun   No        0.160113
#       Yes       0.187250
# Thur  No        0.160298
#       Yes       0.163863
# Name: tip_pct, dtype: float64

# %%
grouped_pct.agg(["mean", "std", peak_to_peak])
# Out:
#                  mean       std  peak_to_peak
# day  smoker
# Fri  No      0.151650  0.028123      0.067349
#      Yes     0.174783  0.051293      0.159925
# Sat  No      0.158048  0.039767      0.235193
#      Yes     0.147906  0.061375      0.290095
# Sun  No      0.160113  0.042347      0.193226
#      Yes     0.187250  0.154134      0.644685
# Thur No      0.160298  0.038774      0.193350
#      Yes     0.163863  0.039389      0.151240

# %%
grouped_pct.agg([("average", "mean"), ("stdev", np.std)])
# Out:
#               average     stdev
# day  smoker
# Fri  No      0.151650  0.028123
#      Yes     0.174783  0.051293
# Sat  No      0.158048  0.039767
#      Yes     0.147906  0.061375
# Sun  No      0.160113  0.042347
#      Yes     0.187250  0.154134
# Thur No      0.160298  0.038774
#      Yes     0.163863  0.039389

# %%
functions = ["count", "mean", "max"]

# %%
result = grouped[["tip_pct", "total_bill"]].agg(functions)
result
# Out:
#             tip_pct                     total_bill
#               count      mean       max      count       mean    max
# day  smoker
# Fri  No           4  0.151650  0.187735          4  18.420000  22.75
#      Yes         15  0.174783  0.263480         15  16.813333  40.17
# Sat  No          45  0.158048  0.291990         45  19.661778  48.33
#      Yes         42  0.147906  0.325733         42  21.276667  50.81
# Sun  No          57  0.160113  0.252672         57  20.506667  48.17
#      Yes         19  0.187250  0.710345         19  24.120000  45.35
# Thur No          45  0.160298  0.266312         45  17.113111  41.19
#      Yes         17  0.163863  0.241255         17  19.190588  43.11

# %%
grouped.agg({"tip_pct" : ["min", "max", "mean", "std"],
   ....:              "size" : "sum"})
# Out:
#               tip_pct                               size
#                   min       max      mean       std  sum
# day  smoker
# Fri  No      0.120385  0.187735  0.151650  0.028123    9
#      Yes     0.103555  0.263480  0.174783  0.051293   31
# Sat  No      0.056797  0.291990  0.158048  0.039767  115
#      Yes     0.035638  0.325733  0.147906  0.061375  104
# Sun  No      0.059447  0.252672  0.160113  0.042347  167
#      Yes     0.065660  0.710345  0.187250  0.154134   49
# Thur No      0.072961  0.266312  0.160298  0.038774  112
#      Yes     0.090014  0.241255  0.163863  0.039389   40

# %%
def top(df, n=5, column="tip_pct"):
   ....:     return df.sort_values(column, ascending=False)[:n]

# %%
 top(tips, n=6)
# Out:
#      total_bill   tip smoker  day    time  size   tip_pct
# 172        7.25  5.15    Yes  Sun  Dinner     2  0.710345
# 178        9.60  4.00    Yes  Sun  Dinner     2  0.416667
# 67         3.07  1.00    Yes  Sat  Dinner     1  0.325733
# 232       11.61  3.39     No  Sat  Dinner     2  0.291990
# 183       23.17  6.50    Yes  Sun  Dinner     4  0.280535
# 109       14.31  4.00    Yes  Sat  Dinner     2  0.279525

# %%
tips.groupby("smoker").apply(top)
# Out:
#             total_bill   tip smoker   day    time  size   tip_pct
# smoker
# No     232       11.61  3.39     No   Sat  Dinner     2  0.291990
#        149        7.51  2.00     No  Thur   Lunch     2  0.266312
#        51        10.29  2.60     No   Sun  Dinner     2  0.252672
#        185       20.69  5.00     No   Sun  Dinner     5  0.241663
#        88        24.71  5.85     No  Thur   Lunch     2  0.236746
# Yes    172        7.25  5.15    Yes   Sun  Dinner     2  0.710345
#        178        9.60  4.00    Yes   Sun  Dinner     2  0.416667
#        67         3.07  1.00    Yes   Sat  Dinner     1  0.325733
#        183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
#        109       14.31  4.00    Yes   Sat  Dinner     2  0.279525

# %%
tips.groupby(["smoker", "day"]).apply(top, n=1, column="total_bill")
# Out:
#                  total_bill    tip smoker   day    time  size   tip_pct
# smoker day
# No     Fri  94        22.75   3.25     No   Fri  Dinner     2  0.142857
#        Sat  212       48.33   9.00     No   Sat  Dinner     4  0.186220
#        Sun  156       48.17   5.00     No   Sun  Dinner     6  0.103799
#        Thur 142       41.19   5.00     No  Thur   Lunch     5  0.121389
# Yes    Fri  95        40.17   4.73    Yes   Fri  Dinner     4  0.117750
#        Sat  170       50.81  10.00    Yes   Sat  Dinner     3  0.196812
#        Sun  182       45.35   3.50    Yes   Sun  Dinner     3  0.077178
#        Thur 197       43.11   5.00    Yes  Thur   Lunch     4  0.115982

# %%
tips.groupby("smoker", group_keys=False).apply(top)
# Out:
#      total_bill   tip smoker   day    time  size   tip_pct
# 232       11.61  3.39     No   Sat  Dinner     2  0.291990
# 149        7.51  2.00     No  Thur   Lunch     2  0.266312
# 51        10.29  2.60     No   Sun  Dinner     2  0.252672
# 185       20.69  5.00     No   Sun  Dinner     5  0.241663
# 88        24.71  5.85     No  Thur   Lunch     2  0.236746
# 172        7.25  5.15    Yes   Sun  Dinner     2  0.710345
# 178        9.60  4.00    Yes   Sun  Dinner     2  0.416667
# 67         3.07  1.00    Yes   Sat  Dinner     1  0.325733
# 183       23.17  6.50    Yes   Sun  Dinner     4  0.280535
# 109       14.31  4.00    Yes   Sat  Dinner     2  0.279525

# %%
frame = pd.DataFrame({"data1": np.random.standard_normal(1000),
   ....:                       "data2": np.random.standard_normal(1000)})

# %%
quartiles = pd.cut(frame["data1"], 4)

# %%
def get_stats(group):
   ....:     return pd.DataFrame(
   ....:         {"min": group.min(), "max": group.max(),
   ....:         "count": group.count(), "mean": group.mean()}
   ....:     )

# %%
frame
# Out:
#         data1     data2
# 0   -0.690205  0.426609
# 1   -2.520314  2.473573
# 2   -0.374353 -0.345312
# 3   -0.657264 -1.030162
# 4   -0.354701 -1.651117
# ..        ...       ...
# 995  0.289160  2.202775
# 996  0.583959  0.285591
# 997  0.327153  1.032623
# 998  0.277032 -0.958341
# 999  0.943690  1.224735
#
# [1000 rows x 2 columns]

# %%
grouped = frame.groupby(quartiles)
group.apply(get_stats)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/nanops.py:1692, in _ensure_numeric(x)
#    1691 try:
# -> 1692     x = float(x)
#    1693 except (TypeError, ValueError):
#    1694     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: 'b'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/nanops.py:1696, in _ensure_numeric(x)
#    1695 try:
# -> 1696     x = complex(x)
#    1697 except ValueError as err:
#    1698     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 grouped = frame.groupby(quartiles)
# ----> 2 group.apply(get_stats)
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[49], line 4, in get_stats(group)
#       1 def get_stats(group):
#       2     return pd.DataFrame(
#       3         {"min": group.min(), "max": group.max(),
# ----> 4         "count": group.count(), "mean": group.mean()}
#       5     )
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File ~/Dev/PythonForDataAnalysis/venv/lib/python3.8/site-packages/pandas/core/nanops.py:1699, in _ensure_numeric(x)
#    1696             x = complex(x)
#    1697         except ValueError as err:
#    1698             # e.g. "foo"
# -> 1699             raise TypeError(f"Could not convert {x} to numeric") from err
#    1700 return x
#
# TypeError: Could not convert b to numeric

# %%
grouped.agg(["min", "max", "count", "mean"])
# Out:
#                      data1                               data2            \
#                        min       max count      mean       min       max
# data1
# (-3.006, -1.432] -2.999363 -1.435778    71 -1.790189 -2.201583  2.473573
# (-1.432, 0.135]  -1.430394  0.134570   472 -0.484759 -3.795103  2.787661
# (0.135, 1.702]    0.138442  1.687740   393  0.769121 -3.096504  2.664363
# (1.702, 3.269]    1.706920  3.268787    64  2.115793 -2.389478  2.232515
#
#
#                  count      mean
# data1
# (-3.006, -1.432]    71  0.019236
# (-1.432, 0.135]    472 -0.031761
# (0.135, 1.702]     393 -0.032975
# (1.702, 3.269]      64  0.214848

# %%
s = pd.Series(np.random.standard_normal(6))

# %%
s[::2] = np.nan

# %%
s.fillna(s.mean())
# Out:
# 0    0.206061
# 1    0.881553
# 2    0.206061
# 3   -0.875769
# 4    0.206061
# 5    0.612398
# dtype: float64

# %%
states = ["Ohio", "New York", "Vermont", "Florida",
   .....:           "Oregon", "Nevada", "California", "Idaho"]
group_key = ["East", "East", "East", "East",
   .....:              "West", "West", "West", "West"]

# %%
data = pd.Series(np.random.standard_normal(8), index=states)
data
# Out:
# Ohio          0.459086
# New York     -1.086032
# Vermont       0.270950
# Florida       0.959164
# Oregon       -1.310737
# Nevada       -0.688076
# California    1.393932
# Idaho         1.074995
# dtype: float64

# %%
data[["Vermont", "Nevada", "Idaho"]] = np.nan

# %%
data.groupby(group_key).size()
# Out:
# East    4
# West    4
# dtype: int64

# %%
def fill_mean(group):
   .....:     return group.fillna(group.mean())

# %%
data.groupby(group_key).apply(fill_mean)
# Out:
# East  Ohio          0.459086
#       New York     -1.086032
#       Vermont       0.110739
#       Florida       0.959164
# West  Oregon       -1.310737
#       Nevada        0.041597
#       California    1.393932
#       Idaho         0.041597
# dtype: float64

# %%
suits = ["H", "S", "C", "D"]  # Hearts, Spades, Clubs, Diamonds
card_val = (list(range(1, 11)) + [10] * 3) * 4
base_names = ["A"] + list(range(2, 11)) + ["J", "K", "Q"]
cards = []
for suit in suits:
    cards.extend(str(num) + suit for num in base_names)

deck = pd.Series(card_val, index=cards)

# %%
deck.head(13)
# Out:
# AH      1
# 2H      2
# 3H      3
# 4H      4
# 5H      5
# 6H      6
# 7H      7
# 8H      8
# 9H      9
# 10H    10
# JH     10
# KH     10
# QH     10
# dtype: int64

# %%
def draw(deck, n=5):
   .....:     return deck.sample(n)

# %%
def get_suit(card):
   .....:     # last letter is suit
   .....:     return card[-1]

# %%
deck.groupby(get_suit).apply(draw, n=2)
# Out:
# C  2C      2
#    9C      9
# D  2D      2
#    3D      3
# H  5H      5
#    10H    10
# S  2S      2
#    4S      4
# dtype: int64

# %%
df = pd.DataFrame({"category": ["a", "a", "a", "a",
   .....:                                 "b", "b", "b", "b"],
   .....:                    "data": np.random.standard_normal(8),
   .....:                    "weights": np.random.uniform(size=8)})

# %%
grouped = df.groupby("category")

# %%
def get_wavg(group):
   .....:     return np.average(group["data"], weights=group["weights"])

# %%
grouped.apply(get_wavg)
# Out:
# category
# a   -0.256911
# b    0.278946
# dtype: float64

# %%
df = pd.DataFrame({'key': ['a', 'b', 'c'] * 4,
   .....:                    'value': np.arange(12.)})

# %%
g = df.groupby('key')['value']
g.mean()
# Out:
# key
# a    4.5
# b    5.5
# c    6.5
# Name: value, dtype: float64

# %%
def get_mean(group):
   .....:     return group.mean()

# %%
g.transform(get_mean)
# Out:
# 0     4.5
# 1     5.5
# 2     6.5
# 3     4.5
# 4     5.5
# 5     6.5
# 6     4.5
# 7     5.5
# 8     6.5
# 9     4.5
# 10    5.5
# 11    6.5
# Name: value, dtype: float64

# %%
g.transform('mean')
# Out:
# 0     4.5
# 1     5.5
# 2     6.5
# 3     4.5
# 4     5.5
# 5     6.5
# 6     4.5
# 7     5.5
# 8     6.5
# 9     4.5
# 10    5.5
# 11    6.5
# Name: value, dtype: float64

# %%
normalized = (df['value'] - g.transform('mean')) / g.transform('std')

# %%
tips.pivot_table(index=["day", "smoker"],
   .....:                  values=["size", "tip", "tip_pct", "total_bill"])
# Out:
#                  size       tip   tip_pct  total_bill
# day  smoker
# Fri  No      2.250000  2.812500  0.151650   18.420000
#      Yes     2.066667  2.714000  0.174783   16.813333
# Sat  No      2.555556  3.102889  0.158048   19.661778
#      Yes     2.476190  2.875476  0.147906   21.276667
# Sun  No      2.929825  3.167895  0.160113   20.506667
#      Yes     2.578947  3.516842  0.187250   24.120000
# Thur No      2.488889  2.673778  0.160298   17.113111
#      Yes     2.352941  3.030000  0.163863   19.190588

# %%
tips.pivot_table(index=["time", "day"], columns="smoker",
   .....:                  values=["tip_pct", "size"])
# Out:
#                  size             tip_pct
# smoker             No       Yes        No       Yes
# time   day
# Dinner Fri   2.000000  2.222222  0.139622  0.165347
#        Sat   2.555556  2.476190  0.158048  0.147906
#        Sun   2.929825  2.578947  0.160113  0.187250
#        Thur  2.000000       NaN  0.159744       NaN
# Lunch  Fri   3.000000  1.833333  0.187735  0.188937
#        Thur  2.500000  2.352941  0.160311  0.163863

# %%
tips.pivot_table(index=["time", "size", "smoker"], columns="day",
   .....:                  values="tip_pct", fill_value=0)
# Out:
# day                      Fri       Sat       Sun      Thur
# time   size smoker
# Dinner 1    No      0.000000  0.137931  0.000000  0.000000
#             Yes     0.000000  0.325733  0.000000  0.000000
#        2    No      0.139622  0.162705  0.168859  0.159744
#             Yes     0.171297  0.148668  0.207893  0.000000
#        3    No      0.000000  0.154661  0.152663  0.000000
#             Yes     0.000000  0.144995  0.152660  0.000000
#        4    No      0.000000  0.150096  0.148143  0.000000
#             Yes     0.117750  0.124515  0.193370  0.000000
#        5    No      0.000000  0.000000  0.206928  0.000000
#             Yes     0.000000  0.106572  0.065660  0.000000
#        6    No      0.000000  0.000000  0.103799  0.000000
# Lunch  1    No      0.000000  0.000000  0.000000  0.181728
#             Yes     0.223776  0.000000  0.000000  0.000000
#        2    No      0.000000  0.000000  0.000000  0.166005
#             Yes     0.181969  0.000000  0.000000  0.158843
#        3    No      0.187735  0.000000  0.000000  0.084246
#             Yes     0.000000  0.000000  0.000000  0.204952
#        4    No      0.000000  0.000000  0.000000  0.138919
#             Yes     0.000000  0.000000  0.000000  0.155410
#        5    No      0.000000  0.000000  0.000000  0.121389
#        6    No      0.000000  0.000000  0.000000  0.173706

# %%
from io import StringIO
data = """Sample  Nationality  Handedness
1   USA  Right-handed
2   Japan    Left-handed
3   USA  Right-handed
4   Japan    Right-handed
5   Japan    Left-handed
6   Japan    Right-handed
7   USA  Right-handed
8   USA  Left-handed
9   Japan    Right-handed
10  USA  Right-handed"""

data = pd.read_table(StringIO(data), sep="\s+")

# %%
data
# Out:
#    Sample Nationality    Handedness
# 0       1         USA  Right-handed
# 1       2       Japan   Left-handed
# 2       3         USA  Right-handed
# 3       4       Japan  Right-handed
# 4       5       Japan   Left-handed
# 5       6       Japan  Right-handed
# 6       7         USA  Right-handed
# 7       8         USA   Left-handed
# 8       9       Japan  Right-handed
# 9      10         USA  Right-handed

# %%
pd.crosstab(data["Nationality"], data["Handedness"], margins=True)
# Out:
# Handedness   Left-handed  Right-handed  All
# Nationality
# Japan                  2             3    5
# USA                    1             4    5
# All                    3             7   10
